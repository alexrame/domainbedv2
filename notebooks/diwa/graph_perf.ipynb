# %%
topk = [2, 3, 5, 8, 10, 15, 20, 25, 30, 40, 50, 60, 80, 100, 120, 140, 160, 180]
perfs = [0.671, 0.680, 0.684, 0.681, 0.686, 0.687, 0.695, 0.693, 0.695, 0.701, 0.702, 0.701, 0.698, 0.701, 0.702, 0.701, 0.699, 0.699]

# %%
import matplotlib.pyplot as plt

# %%
plt.xlabel("topk")
plt.ylabel("soup acc.")
plt.plot(topk, perfs)# label="int."+label)
