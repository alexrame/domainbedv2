# %%
# %load_ext autoreload
# %autoreload 2
from codeplot.analyze_diversity import *
from codeplot.plot import save_fig

# %%
plt.rcParams["figure.figsize"] = (6, 5)

# %%
# lsoup_hp601
fig_ood_hess = plot_boxplot_hess(key1="", key2="hess", title="Hessian trace in test OOD", limits=None)

# %%
save_fig(fig_ood_hess, "boxplot_ood_hess_ermwasamf.png")

# %%
# lsoup_hp601
fig_train_hess = plot_boxplot_hess(key1="train_", key2="hess", title="Hessian trace in train IID", limits=[0, 15000])

# %%
save_fig(fig_train_hess, "boxplot_masam_train_hess.png")

# %%
# lsoup_hp601
fig_train_acc = plot_boxplot_hess(key1="train_", key2="", title="Train OOD Accuracy", limits=None)

# %%
# lsoup_hp601
fig_ood_acc = plot_boxplot_hess(key1="", key2="", title="Accuracy in test OOD", limits=None)

# %%
save_fig(fig_ood_acc, "boxplot_masam_ood_acc_ermwa.png")
