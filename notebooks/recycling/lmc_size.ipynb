# %%
# %load_ext autoreload
# %autoreload 2
import sys
import collections
import numpy as np
# sys.path.append("/private/home/alexandrerame/domainbedv2/")
# sys.path.append("/private/home/alexandrerame/slurmconfig/notebook/data")

sys.path.append("/Users/alexandrerame/code_repository/codedev/domainbedv2")
# sys.path.append("/Users/alexandrerame/code_repository/notebook/data")

# sys.path.append("/home/rame/domainbedv2")
# sys.path.append("/data/rame/fb_slurmconfig/notebook/data")

from domainbed.codeplot import plot

# %%
plot.plt.style.use('default')
from matplotlib import rc

plot.plt.rcParams["figure.figsize"] = (5, 5)
plot.plt.rcParams['text.usetex'] = True
plot.plt.rcParams['text.latex.preamble'] = [r"\usepackage{amsmath}"]
plot.plt.rcParams['font.family'] = 'serif'
# plot.plt.rcParams['text.usetex'] = True
# plot.plt.rcParams['font.family'] = 'serif'
# plot.plt.rcParams['font.serif'] = 'Times Roman'
# plot.FORMAT_X = 1
# plot.FORMAT_Y = 3

# %%
dict_data_to_domains = {
    "home": ["Art", "Clipart", "Product", "Photo"],
    "pacs": ["Art", "Cartoon", "Photo", "Sketch"],
    "terra": ["L100", "L38", "L43", "L46"],
    "vlcs": ["Caltech", "LabelMe", "SUN", "VOC"],
    "came": ["hospital 0", "hospital 1", "hospital 2", "hospital 3"],
}

# %%
l_pacs_vit = []
l_pacs_vit.append({"acc": 0.82666015625, "dirs": "pacs0_erm_lpvlcs_0524,pacs0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 1, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.0, "printres": "&&"})
l_pacs_vit.append({"acc": 0.85498046875, "dirs": "pacs0_erm_lpvlcs_0524,pacs0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.09999999999999998, "printres": "&&"})
l_pacs_vit.append({"acc": 0.87744140625, "dirs": "pacs0_erm_lpvlcs_0524,pacs0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.2, "printres": "&&"})
l_pacs_vit.append({"acc": 0.89111328125, "dirs": "pacs0_erm_lpvlcs_0524,pacs0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.3, "printres": "&&"})
l_pacs_vit.append({"acc": 0.90087890625, "dirs": "pacs0_erm_lpvlcs_0524,pacs0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.4, "printres": "&&"})
l_pacs_vit.append({"acc": 0.89990234375, "dirs": "pacs0_erm_lpvlcs_0524,pacs0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.5, "printres": "&&"})
l_pacs_vit.append({"acc": 0.89453125, "dirs": "pacs0_erm_lpvlcs_0524,pacs0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.6, "printres": "&&"})
l_pacs_vit.append({"acc": 0.88916015625, "dirs": "pacs0_erm_lpvlcs_0524,pacs0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.7, "printres": "&&"})
l_pacs_vit.append({"acc": 0.86669921875, "dirs": "pacs0_erm_lpvlcs_0524,pacs0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.8, "printres": "&&"})
l_pacs_vit.append({"acc": 0.84130859375, "dirs": "pacs0_erm_lpvlcs_0524,pacs0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.9, "printres": "&&"})
l_pacs_vit.append({"acc": 0.81103515625, "dirs": "pacs0_erm_lpvlcs_0524,pacs0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 1, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 1.0, "printres": "&&"})

dataset = "pacs"
testenv = 0
do_save = 1
plot.dict_key_to_label["acc"] = "OOD test acc. on domain " + dict_data_to_domains[dataset][testenv]
name = dataset + str(testenv)

linestyles = ["solid", "dashed", "dotted", "dashdot"]

fig_dr = plot.plot_key(
    [l_pacs_vit],
    key_x="weighting",
    key_y="acc",
    labels=["TerraInc to VLCS"],
    order=4,
    loc="lower right",
    _dict_key_to_label={},
    linestyles=linestyles
)
if do_save:
    plot.save_fig(
        fig_dr,
        name + "_lmc_hyp2_ood_vit.pdf",
        folder="/Users/alexandrerame/code_repository/tex/model_recycling_icml/images/filesdevfair/lmc/"
    )

# %%
l_home_vit = []
l_home_vit.append({"acc": 0.700041203131438, "dirs": "home0_erm_lpvlcs_0524,home0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 1, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.0, "printres": "&&"})
l_home_vit.append({"acc": 0.7288833951380305, "dirs": "home0_erm_lpvlcs_0524,home0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.09999999999999998, "printres": "&&"})
l_home_vit.append({"acc": 0.7515451174289246, "dirs": "home0_erm_lpvlcs_0524,home0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.2, "printres": "&&"})
l_home_vit.append({"acc": 0.7626699629171817, "dirs": "home0_erm_lpvlcs_0524,home0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.3, "printres": "&&"})
l_home_vit.append({"acc": 0.7709105892047796, "dirs": "home0_erm_lpvlcs_0524,home0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.4, "printres": "&&"})
l_home_vit.append({"acc": 0.7754429336629584, "dirs": "home0_erm_lpvlcs_0524,home0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.5, "printres": "&&"})
l_home_vit.append({"acc": 0.7676143386897404, "dirs": "home0_erm_lpvlcs_0524,home0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.6, "printres": "&&"})
l_home_vit.append({"acc": 0.7515451174289246, "dirs": "home0_erm_lpvlcs_0524,home0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.7, "printres": "&&"})
l_home_vit.append({"acc": 0.7354758961681088, "dirs": "home0_erm_lpvlcs_0524,home0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.8, "printres": "&&"})
l_home_vit.append({"acc": 0.7099299546765554, "dirs": "home0_erm_lpvlcs_0524,home0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 2, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 0.9, "printres": "&&"})
l_home_vit.append({"acc": 0.672847136382365, "dirs": "home0_erm_lpvlcs_0524,home0_erm_lpterra_0524", "dirslen": 2, "length": 2, "lengthf": 1, "step": "best", "testenv": 0, "topk": "-1", "trialseed": 0, "weighting": 1.0, "printres": "&&"})

dataset = "home"
testenv = 0
do_save = 1
plot.dict_key_to_label["acc"] = "OOD test acc. on domain " + dict_data_to_domains[dataset][testenv]
name = dataset + str(testenv)

linestyles = ["solid", "dashed", "dotted", "dashdot"]

fig_dr = plot.plot_key(
    [l_home_vit],
    key_x="weighting",
    key_y="acc",
    labels=["TerraInc to VLCS"],
    order=4,
    loc="lower right",
    _dict_key_to_label={},
    linestyles=linestyles
)
if do_save:
    plot.save_fig(
        fig_dr,
        name + "_lmc_hyp2_ood_vit.pdf",
        folder=
        "/Users/alexandrerame/code_repository/tex/model_recycling_icml/images/filesdevfair/lmc/"
    )

# %%
from notebooks.data.recycling import lmc_size

# %%
dataset = "vlcs"
testenv = 1
do_save = 0
plot.dict_key_to_label["acc"] = "OOD test acc. on domain " + dict_data_to_domains[dataset][testenv]
name = dataset + str(testenv)

linestyles = ["solid", "dashed", "dotted", "dashdot"]

fig_dr = plot.plot_key(
    lmc_size.l_vlcs_1[:3],
    key_x="weighting",
    key_y="acc",
    labels=lmc_size.labels,
    order=4,
    loc="lower right",
    _dict_key_to_label={},
    linestyles=linestyles
)
if do_save:
    plot.save_fig(fig_dr, "lmc/" + name + "_lmc_obs2_ood.pdf")
