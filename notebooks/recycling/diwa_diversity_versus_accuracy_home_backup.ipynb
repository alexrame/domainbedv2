# %%
# %load_ext autoreload
# %autoreload 2
import sys
import collections
import numpy as np
sys.path.append("/private/home/alexandrerame/domainbedv2/")
sys.path.append("/private/home/alexandrerame/slurmconfig/notebook/data")
from domainbed.codeplot import plot

plot.plt.rcParams["figure.figsize"] = (5, 5)

# %%
from diwadinit import diwa_dnim_pacshome, diwa_fdnim_home
from diwadinit.home import home0_lmc_pacsdnim_filter

# %%
from diversity.home import home0_isit,  home0_idit, home0_idit_dnspec
from diwadinit.home import home0_llm_idit_filter, home0_llm_idit_rank

# %%
from diversity.home import home0_div_imdn0dn1_idit_step, home0_div_imdn0dn1_isit_step_top2

plot.MUL = 0

# %% [markdown]
# # Linear mode connectivity for fts with different inits

# %%
# Final
list_indexes = [0, 1, 2]
fig_dr = plot.plot_key(
    home0_llm_idit_filter.l, key1="train_acc", key2="acc", labels=home0_llm_idit_filter.labels, order=0,
    loc="upper left",
    list_indexes=list_indexes,
    keycolor="weighting",
    lambda_filtering=lambda x: x["step"] == "last" and x["testenv"] == 0,
    title="Lack of IID-OOD correlation when WA from multiple inits"
)

# %%
# Final
list_indexes = [2, 5, 7]
list_indexes = [1, 4, 7]
fig_dr = plot.plot_key(
    home0_llm_idit_filter.l, key1="train_acc", key2="acc", labels=home0_llm_idit_filter.labels, order=0,
    loc="upper left",
    list_indexes=list_indexes,
    keycolor="weighting",
    lambda_filtering=lambda x: x["step"] == "last" and x["testenv"] == 3,
    title="Lack of IID-OOD correlation when WA from multiple inits"
)

# %%
list_indexes = [0]
fig_dr = plot.plot_key(
    home0_llm_idit_filter.l,
    key1="train_acc",
    key2="acc",
    labels=home0_llm_idit_filter.labels,
    order=0,
    loc="lower left",
    list_indexes=list_indexes,
    keycolor="weighting",
    colors=["Blues"],
    lambda_filtering=lambda x: x.get("testenv", 0) == 0 and x["step"] == "last",
    title="Lack of IID-OOD correlation when WA from multiple inits"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1114995/1401253533.py in <module>
#       1 list_indexes = [0]
#       2 fig_dr = plot.plot_key(
# ----> 3     home0_llm_idit_filter.l,
#       4     key1="train_acc",
#       5     key2="acc",
#
# NameError: name 'home0_llm_idit_filter' is not defined

# %%
list_indexes = None
fig_dr = plot.plot_key(
    diwa_dnim_pacshome.l,
    key1="weighting",
    key2="acc",
    #keyerror="acc_std",
    labels=diwa_dnim_pacshome.labels,
    order=2,
    loc="lower left",
    list_indexes=list_indexes,
    key_clustering="weighting",

)
plot.save_fig(fig_dr, "fig_diwa_dnim_lambda_vs_oodacc_" + "pacs2" + ".png")

# %%
list_indexes = None
fig_dr = plot.plot_key(
    diwa_dnim_pacshome.l[3:4],
    key1="train_acc_netm",
    key2="acc_netm",
    # labels=diwa_dnim_pacshome.labels,
    order=0,
    loc="lower right",
    list_indexes=list_indexes,
    #keycolor="1-weighting",
    colors=None,#["Blues", "Reds"],
    #key_clustering="weighting",
    labels=["$\lambda$ from 0 (light blue) to 1 (dark blue)"],
    lambda_filtering=lambda x: x["dirs"].startswith("home") and x["testenv"] == 0 and "train_acc_netm" in x,
#    title="Lack of IID-OOD correlation when WA from multiple inits"
)
plot.save_fig(fig_dr, "diwa/fig_erm_dnim_iid_vs_ood_home0.png")

# %%
[l["acc"] for l in home0_lmc_pacsdnim_filter.l[0] if l["weighting"] == 0]
# Out:
# [0.6716110424392254,
#  0.676967449526164,
#  0.6695508858673259,
#  0.6555418211784095,
#  0.672847136382365,
#  0.6658426040379068,
#  0.6711990111248455,
#  0.673259167696745,
#  0.6646065100947672,
#  0.6736711990111248,
#  0.6670786979810466,
#  0.6711990111248455,
#  0.6646065100947672,
#  0.6716110424392254,
#  0.6674907292954264,
#  0.6679027606098064,
#  0.669138854552946,
#  0.6629583848372477,
#  0.6580140090646889,
#  0.661722290894108]

# %%
list_indexes = None
plot.SIZE = "large"

fig_dr = plot.plot_key(
    home0_lmc_pacsdnim_filter.l[1:2],
    key1="train_acc",
    key2="acc",
    order=0,
    loc="lower right",
    list_indexes=list_indexes,
    colors=None,
    keysplit="1-weighting",
    labels="fromsplit",
    label="$\mu={:.2f}$",
    kwargs={"s": 200},
    lambda_filtering=lambda x: x["testenv"] == 0,
)
plot.save_fig(fig_dr, "diwa/fig_diwa_dnpacs_iid_vs_ood_home0_mean.png")

# %%
list_indexes = None
# labels = [
#     "$\lambda={:.2f}$".format(label)
#     for label in [0.0, 0.20, 0.33, 0.40, 0.50, 0.67, 0.80, 0.91, 1.0]
# ][::-1]
plot.SIZE="large"

fig_dr = plot.plot_key(
    diwa_dnim_pacshome.l[3:4],
    key1="train_acc",
    key2="acc",
    order=0,
    loc="upper left",
    list_indexes=list_indexes,
    #keycolor="1-weighting",
    colors=None,
    keysplit="1-weighting",
    labels="fromsplit",
    label="$\lambda={:.2f}$",
    lambda_filtering=lambda x: x["dirs"].startswith("home") and x["testenv"] == 0,
    #    title="Lack of IID-OOD correlation when WA from multiple inits"
)
# plot.save_fig(fig_dr, "diwa/fig_diwa_dnim_iid_vs_ood_home0.png")

# %%
list_indexes = None
# labels = [
#     "$\lambda={:.2f}$".format(label)
#     for label in [0.0, 0.20, 0.33, 0.40, 0.50, 0.67, 0.80, 0.91, 1.0]
# ][::-1]
plot.SIZE="large"

fig_dr = plot.plot_key(
    diwa_fdnim_home.l[-1:],
    key1="train_acc",
    key2="acc",
    order=0,
    loc="upper left",
    list_indexes=list_indexes,
    #keycolor="1-weighting",
    colors=None,
    keysplit="1-weighting",
    labels="fromsplit",
    label="$\lambda={:.2f}$",
    lambda_filtering=lambda x: x["dirs"].startswith("home") and x["testenv"] == 0,
    #    title="Lack of IID-OOD correlation when WA from multiple inits"
)
# plot.save_fig(fig_dr, "diwa/fig_diwa_dnim_iid_vs_ood_home0.png")

# %%
list_indexes = None
# labels = [
#     "$\lambda={:.2f}$".format(label)
#     for label in [0.0, 0.20, 0.33, 0.40, 0.50, 0.67, 0.80, 0.91, 1.0]
# ][::-1]
plot.SIZE="large"
fig_dr = plot.plot_key(
    diwa_dnim_pacshome.l[3:4],
    key1="train_acc",
    key2="acc",
    order=0,
    loc="lower right",
    list_indexes=list_indexes,
    #keycolor="1-weighting",
    colors=None,
    keysplit="1-weighting",
    labels="fromsplit",
    label="$\mu={:.2f}$",
    lambda_filtering=lambda x: x["dirs"].startswith("home") and x["testenv"] == 0,
    kwargs={"s": 200}
    #    title="Lack of IID-OOD correlation when WA from multiple inits"
)
plot.save_fig(fig_dr, "diwa/fig_diwa_dnim_iid_vs_ood_home0_mean.png")

# %%
# Final
list_indexes = [0, 1, 2]
fig_dr = plot.plot_key(
    home0_llm_idit_filter.l, key1="train_acc", key2="acc", labels=home0_llm_idit_filter.labels, order=0,
    loc="upper left",
    list_indexes=list_indexes,
    keycolor="weighting",
    lambda_filtering=lambda x: x["step"] == "last" and x["testenv"] == 0,
    title="Lack of IID-OOD correlation when WA from multiple inits"
)

# %%
len(home0_llm_idit_filter.labels)

# %%
list_indexes = 0+np.array([15, 16])
fig_dr = plot.plot_key(
    home0_llm_idit_filter.l,
    key1="train_acc",
    key2="acc",
    labels=home0_llm_idit_filter.labels,
    order=0,
    loc="upper left",
    list_indexes=list_indexes,
    keycolor="weighting",
)

# %%
list_indexes = 0+np.array([0, 3, 6, 9])
list_indexes = 0+np.array([0, 3, 4, 5])
list_indexes = 0+np.array([12, 13, 14, 15, 16, 17])
fig_dr = plot.plot_key(
    home0_llm_idit_rank.l, key1="weighting", key2="train_acc", labels=home0_llm_idit_rank.labels, order=2, loc="lower left",
    list_indexes=list_indexes
)

# %% [markdown]
# # Diwa or recycling ?

# %%
list_indexes = None
fig_dr = plot.plot_key(
    diwa_dnim_pacshome.l,
    key1="weighting",
    key2="acc",
    #keyerror="acc_std",
    labels=diwa_dnim_pacshome.labels,
    order=2,
    loc="lower left",
    list_indexes=list_indexes,
    key_clustering="weighting",
    lambda_filtering=lambda x: x["dirs"].startswith("pacs") and x["testenv"] == 2,
)
plot.save_fig(fig_dr, "fig_diwa_dnim_lambda_vs_oodacc_" + "pacs2" + ".png")

# %%
list_indexes = None
fig_dr = plot.plot_key(
    diwa_dnim_pacshome.l,
    key1="1-weighting",
    key2="acc",
    #keyerror="acc_std",
    labels=diwa_dnim_pacshome.labels,
    order=2,
    loc="lower left",
    list_indexes=list_indexes,
    _dict_key_to_label={"1-weighting": r"$\mu$"},
    keyclustering="weighting",
    lambda_filtering=lambda x: x["dirs"].startswith("home") and x["testenv"] == 0,
)
plot.save_fig(fig_dr, "diwa/fig_diwa_dnim_lambda_vs_oodacc_" + "home0" + ".png")

# %%
list_indexes = 0 + np.array([15, 16])
fig_dr = plot.plot_key(
    home0_llm_idit_filter.l,
    key1="weighting",
    key2="train_acc",
    labels=home0_llm_idit_filter.labels,
    order=2,
    loc="lower left",
    list_indexes=list_indexes
)

# %%
list_indexes = 0 + np.array([15, 16])
fig_dr = plot.plot_key(
    home0_llm_idit_filter.l,
    key1="train_acc",
    key2="acc",
    labels=home0_llm_idit_filter.labels,
    order=0,
    loc="lower left",
    list_indexes=list_indexes,
    keycolor="weighting",
    colors=["Blues", "Reds"]
)

# %%
list_indexes = 0+np.array([9, 10, 11])

fig_dr = plot.plot_key(
    home0_llm_idit_rank.l,
    key1="weighting",
    key2="acc",
    labels=home0_llm_idit_rank.labels,
    order=2,
    loc="lower right",
    list_indexes=list_indexes,
)

# %% [markdown]
# # Diversity accuracy

# %%
fig = plot.plot_key(
    home0_div_imdn0dn1_idit_step.l + home0_div_imdn0dn1_isit_step_top2.l,
    labels=home0_div_imdn0dn1_idit_step.labels + home0_div_imdn0dn1_isit_step_top2.labels,
    key1="divr_netm",
    key2="acc_netm",
    lambda_filtering=lambda x: x["step"] == 4900
)

# %%
l = [[line for line in ll if "acc_netm" in line] for ll in home0_idit.l]

fig_dr = plot.plot_key(l, key1="divr_netm", key2="acc_netm", labels=home0_idit.labels)

# %%
fig_dr = plot.plot_key(home0_idit.l+home0_isit.l, key1="1-divq_netm", key2="acc-acc_netm", labels=home0_idit.labels + home0_isit.labels, list_indexes=[0, 21, 28])

# %%
def takeslice(_list, indexes):
    return [_list[i] for i in indexes]

# %%
home0_idit.clean = []
for dirs, list_dict_values in enumerate(home0_idit.l):
    for line in list_dict_values:
        line["dist_lambdas"] = home0_idit.dist_lambdas[dirs]
    home0_idit.clean.append({"dist_lambdas": home0_idit.dist_lambdas[dirs]})
    max_index = list_dict_values.index(max(list_dict_values, key=lambda x: x["train_acc_netm"]))
    for key in list_dict_values[0].keys():
        if isinstance(list_dict_values[0][key], float):
            list_values = np.array([line[key] for line in list_dict_values])
            home0_idit.clean[-1][key + "_std"] = np.std(list_values)
            home0_idit.clean[-1][key + "_conf"] = np.std(list_values) / np.sqrt(len(list_values))
            home0_idit.clean[-1][key + "_max"] = np.max(list_values)
            home0_idit.clean[-1][key + "_maxt"] = list_values[max_index]
            home0_idit.clean[-1][key] = np.mean(list_values)

for dirs, list_dict_values in enumerate(home0_isit.l):
    for line in list_dict_values:
        line["dist_lambdas"] = 0.
    max_index = list_dict_values.index(max(list_dict_values, key=lambda x: x["train_acc_netm"]))
    home0_idit.clean.append({"dist_lambdas": 0.})
    home0_idit.clean[-1]["name"] = home0_isit.labels[dirs]
    for key in list_dict_values[0].keys():
        if isinstance(list_dict_values[0][key], float):
            list_values = np.array([line[key] for line in list_dict_values])
            home0_idit.clean[-1][key + "_std"] = np.std(list_values)
            home0_idit.clean[-1][key + "_conf"] = np.std(list_values)/np.sqrt(len(list_values))
            home0_idit.clean[-1][key + "_max"] = np.max(list_values)
            home0_idit.clean[-1][key + "_maxt"] = list_values[max_index]
            home0_idit.clean[-1][key] = np.mean(list_values)

# %%
fig = plot.plot_key(
    [home0_idit.clean],
    "dist_lambdas",
    "divr_netm",
    # keyerror="1-divq_netm_std",
    order="1",
    loc="no",
    labels=["no"],
    # keyerror="divq_netm_conf",
    #keycolor="divq_netm_std",
    #title="Correlation between different initializations and diversity",
    #\n Color indicates standard deviation."
)
plot.save_fig(fig, "diwa/fig_wadnim_lambda_dr_home0" + ".png")

# %%
fig = plot.plot_key(
    [home0_idit.clean],
    "dist_lambdas",
    "1-divq_netm",
    # keyerror="1-divq_netm_std",
    order="1",
    loc="no",
    labels=["no"],
    # keyerror="divq_netm_conf",
    #keycolor="divq_netm_std",
    #title="Correlation between different initializations and diversity",
    #\n Color indicates standard deviation."
)
plot.save_fig(fig, "diwa/fig_wadnim_lambda_dq_home0" + ".png")

# %%
fig = plot.plot_histogram(
    home0_idit.l,
    labels=home0_idit.labels,
    key="divr_netm",
    limits={},
    lambda_filtering=lambda x: x.get("testenv", 0) == 0,
    list_indexes=range(8)
)
plot.save_fig(fig, "diwa/fig_wadnim_hist_dr_home0" + ".png")

# %%
fig = plot.plot_histogram(
    home0_idit.l,
    labels=home0_idit.labels,
    key="1-divq_netm",
    limits={},
    lambda_filtering=lambda x: x.get("testenv", 0) == 0,
    list_indexes=range(8)
)
#plot.save_fig(fig, "diwa/fig_wadnim_hist_dq_home0" + ".png")

# %%
indexes = [17, 18, 16, 19, 15, 20, 4, 11]
indexes = [17, 18, 4, 11]

fig = plot.plot_histogram(
    (home0_isit.l[1:2] + takeslice(home0_idit.l, indexes)),  # + ,
    labels=(home0_isit.labels[1:2] + takeslice(home0_idit.labels, indexes)),  # + ,
    key="divr_netm",
    limits={},
)

# %%
home0_isit.labels
# Out:
# ['IM', 'WA 4.', 'WA 2.', 'WA 1.', 'WA 0.5', 'WA 0.25', 'WA 0.10', 'DN']

# %%
fig = plot.plot_histogram(
    (takeslice(home0_isit.l, [0, 7]) + takeslice(home0_idit.l, [0])),
    labels=(takeslice(home0_isit.labels, [0, 7]) + takeslice(home0_idit.labels, [0])),
    key="1-divq_netm",
    limits={},
    lambda_filtering=lambda x : True or x["length"] == 2
)

# %%
fig = plot.plot_histogram(
    (home0_isit.l[2:3] + home0_idit.l[8:15])[::-1],# + ,
    labels=(home0_isit.labels[2:3] + home0_idit.labels[8:15])[::-1],# + ,
    key="divr_netm",
    limits={},

)

# %%
fig = plot.plot_histogram(
    home0_idit.l[:8] + home0_isit.l[:1],
    labels=home0_idit.labels[:8] + home0_isit.labels[:1],
    key="divr_netm",
    limits={},

)

# %%
fig = plot.plot_histogram(
    home0_idit.l[:1] + home0_isit.l[:3],
    labels=home0_idit.labels[:1] + home0_isit.labels[:3],
    key="divr_netm",
    limits={},

)

# %%
fig = plot.plot_histogram(
    home0_idit.l + home0_isit.l,
    labels=home0_idit.labels + home0_isit.labels,
    key="divr_netm",
    limits={}
)

# %%
fig = plot_diversity.plot_diversity_aux(home0_idit.l, labels=home0_idit.labels, key="divr_netm", length=None, limits={})

# %% [markdown]
# # Along training steps

# %%
from diversity.home import home_subwa_step
plot.MUL = 1000

# %%
fig = plot.plot_key(
    home_subwa_step.l,
    labels=home_subwa_step.labels,
    key1="acc_wa01",
    key2="acc_wa12",
    list_indexes=range(1),
    lambda_filtering=lambda x: x.get("testenv") == 0 and x["step"] == 100,
    loc="lower left"
)

# %%
plot.MUL = 0
fig = plot.plot_key(
    home0_div_imdn0dn1_idit_step.l + home0_div_imdn0dn1_isit_step_top2.l,
    labels=home0_div_imdn0dn1_idit_step.labels + home0_div_imdn0dn1_isit_step_top2.labels,
    key1="step",
    key2="divr_netm",
    keyclustering="step",
    #keyerror="divq_netm_std",
    lambda_filtering=lambda x: x["step"] > 200 and x.get("testenv", 0) == 0,
    loc="lower right",
    order="1",
    list_indexes=[0, 3, 5]
)
plot.save_fig(fig, "diwa/fig_dnim_step_dr_" + "home0" + ".png")

# %%
plot.MUL = 0
fig = plot.plot_key(
    home0_div_imdn0dn1_idit_step.l + home0_div_imdn0dn1_isit_step_top2.l,
    labels=home0_div_imdn0dn1_idit_step.labels + home0_div_imdn0dn1_isit_step_top2.labels,
    key1="step",
    key2="1-divq_netm",
    keyclustering="step",
    #keyerror="divq_netm_std",
    lambda_filtering=lambda x: x["step"] > 200 and x.get("testenv", 0) == 0,
    loc="lower right",
    order="1",
    list_indexes=[0, 3, 5]
)
plot.save_fig(fig, "diwa/fig_dnim_step_dq_" + "home0" + ".png")

# %%
plot.MUL = 1000
fig = plot.plot_key(
    home0_div_imdn0dn1_idit_step.l + home0_div_imdn0dn1_isit_step_top2.l,
    labels=home0_div_imdn0dn1_idit_step.labels + home0_div_imdn0dn1_isit_step_top2.labels,
    key1="acc_ens",
    key2="acc",
    #key_clustering="step",
    #keyerror="divq_netm_std",
    lambda_filtering=lambda x: x["step"] > 200 and x.get("testenv", 0) == 0,
    loc="upper left",
    order=0,
    diag=True,
    kwargs={"alpha": 0.5},
    list_indexes=[0, 3, 5]
)
plot.save_fig(fig, "diwa/fig_wa_vs_ens_home0" + ".png")

# %%
plot.MUL = 0
fig = plot.plot_key(
    home0_div_imdn0dn1_idit_step.l + home0_div_imdn0dn1_isit_step_top2.l,
    labels=home0_div_imdn0dn1_idit_step.labels + home0_div_imdn0dn1_isit_step_top2.labels,
    key1="divr_netm",
    key2="acc-acc_netm",
    #key_clustering="step",
    #keyerror="divq_netm_std",
    lambda_filtering=lambda x: x["step"] > 200 and x.get("testenv", 0) == 0,
    loc="upper left",
    order=0,
    list_indexes=[0, 3, 5],
    kwargs={"alpha": 0.5}
)
plot.save_fig(fig, "diwa/fig_dnim_dr_gain_home0" + ".png")

# %%
plot.MUL = 0
fig = plot.plot_key(
    home0_div_imdn0dn1_idit_step.l + home0_div_imdn0dn1_isit_step_top2.l,
    labels=home0_div_imdn0dn1_idit_step.labels + home0_div_imdn0dn1_isit_step_top2.labels,
    key1="1-divq_netm",
    key2="acc-acc_netm",
    #key_clustering="step",
    #keyerror="divq_netm_std",
    lambda_filtering=lambda x: x["step"] > 200 and x.get("testenv", 0) == 0,
    loc="upper left",
    order=0,
    list_indexes=[0, 3, 5],
    kwargs={"alpha": 0.5}
)
plot.save_fig(fig, "diwa/fig_dnim_dq_gain_home0" + ".png")

# %%
plot.save_fig(fig, "diwa/fig_dnim_dq_gain_home0" + ".png")

# %%
plot.MUL = 1000
fig = plot.plot_key(
    home0_div_imdn0dn1_idit_step.l + home0_div_imdn0dn1_isit_step_top2.l,
    labels=home0_div_imdn0dn1_idit_step.labels + home0_div_imdn0dn1_isit_step_top2.labels,
    key1="1-divq_netm",
    key2="acc-acc_netm",
    #key_clustering="step",
    #keyerror="divq_netm_std",
    lambda_filtering=lambda x: x["step"] > 200 and x.get("testenv", 0) == 0,
    loc="upper left",
    #order=1,
    list_indexes=[3, 5]
)
# plot.save_fig(fig, "diwa/fig_dnim_dq_gain_home0" + ".png")

# %%
plot.plt.rcParams["figure.figsize"] = (5, 5)
plot.SIZE="small"
fig = plot.plot_histogram_two(
    home0_div_imdn0dn1_idit_step.l + home0_div_imdn0dn1_isit_step_top2.l,
    labels=home0_div_imdn0dn1_idit_step.labels + home0_div_imdn0dn1_isit_step_top2.labels,
    key1="train_divr_netm",
    key2="divr_netm",
    limits={},
    lambda_filtering=lambda x: x["step"] > 200 and x.get("testenv", 0) == 0,
    list_indexes=[0, 3, 5]
)
plot.save_fig(fig, "diwa/fig_dnim_hist_driidood_home0" + ".png")

# %%
plot.plt.rcParams["figure.figsize"] = (5, 5)
plot.SIZE="small"
fig = plot.plot_histogram_two(
    home0_div_imdn0dn1_idit_step.l + home0_div_imdn0dn1_isit_step_top2.l,
    labels=home0_div_imdn0dn1_idit_step.labels + home0_div_imdn0dn1_isit_step_top2.labels,
    key1="1-train_divq_netm",
    key2="1-divq_netm",
    limits={},
    lambda_filtering=lambda x: x["step"] > 200 and x.get("testenv", 0) == 0,
    list_indexes=[0, 3, 5]
)
plot.save_fig(fig, "diwa/fig_dnim_hist_dqiidood_home0" + ".png")

# %%
fig = plot.plot_histogram(
    home0_div_imdn0dn1_idit_step.l + home0_div_imdn0dn1_isit_step_top2.l,
    labels=home0_div_imdn0dn1_idit_step.labels + home0_div_imdn0dn1_isit_step_top2.labels,
    key="1-train_divq_netm",
    limits={},
    lambda_filtering=lambda x: x["step"] > 200 and x.get("testenv", 0) == 0,
    list_indexes=[0, 3, 5]
)
plot.save_fig(fig, "diwa/fig_dnim_hist_dqiid_home0" + ".png")

# %%
plot.MUL = 1000
fig = plot.plot_key(
    home0_div_imdn0dn1_idit_step.l + home0_div_imdn0dn1_isit_step_top2.l,
    labels=home0_div_imdn0dn1_idit_step.labels + home0_div_imdn0dn1_isit_step_top2.labels,
    key1="1-train_divq_netm",
    key2="train_acc-train_acc_netm",
    #key_clustering="step",
    #keyerror="divq_netm_std",
    lambda_filtering=lambda x: x["step"] > 200 and x.get("testenv", 0) == 0,
    loc="upper left",
    order=0,
    list_indexes=[0, 3, 5],
    _dict_key_to_limit={"1-train_divq_netm": [0.02, 0.185], "train_acc-train_acc_netm": [0.0, 0.11]},
)
plot.save_fig(fig, "diwa/fig_dnim_dq_gainiid_home0" + ".png")

# %%
home0_div_imdn0dn1_idit_step.labels + home0_div_imdn0dn1_isit_step_top2.labels
# Out:
# ['IM + DomainNet',
#  'IM + Fusing',
#  'Fusing + DomainNet',
#  'IM + IM',
#  'Fusing + Fusing',
#  'DomainNet + DomainNet']

# %%
labels = [
    "$\kappa=0$ and $\kappa=1$ (IM + DomainNet)",
    "$\kappa=0$ and $\kappa=0.5$",
    "$\kappa=0.5$ and $\kappa=1$",
    "$\kappa=0$ and $\kappa=0$ (IM + IM)",
    "$\kappa=0.5$ and $\kappa=0.5$",
    "$\kappa=1$ and $\kappa=1$ (DomainNet + DomainNet)",
]

# %%
plot.SIZE="small"
fig = plot.plot_histogram(
    home0_div_imdn0dn1_idit_step.l + home0_div_imdn0dn1_isit_step_top2.l,
    labels=labels,#home0_div_imdn0dn1_idit_step.labels + home0_div_imdn0dn1_isit_step_top2.labels,
    key="1-divq_netm",
    loc="lower left",
    limits={},
    lambda_filtering=lambda x: x["step"] > 200 and x.get("testenv", 0) == 0,
    list_indexes=[0, 1, 2, 3, 4, 5]
)
plot.save_fig(fig, "diwa/fig_wadnim_hist_dq_home0" + ".png")

# %%
fig = plot.plot_histogram(
    home0_div_imdn0dn1_idit_step.l + home0_div_imdn0dn1_isit_step_top2.l,
    labels=home0_div_imdn0dn1_idit_step.labels + home0_div_imdn0dn1_isit_step_top2.labels,
    key="1-divq_netm",
    limits={},
    lambda_filtering=lambda x: x["step"] > 200 and x.get("testenv", 0) == 0,
    list_indexes=[0, 3, 5]
)
plot.save_fig(fig, "diwa/fig_dnim_hist_dq_home0" + ".png")

# %%
fig = plot.plot_histogram(
    home0_div_imdn0dn1_idit_step.l + home0_div_imdn0dn1_isit_step_top2.l,
    labels=home0_div_imdn0dn1_idit_step.labels + home0_div_imdn0dn1_isit_step_top2.labels,
    key="divr_netm",
    limits={},
    lambda_filtering=lambda x: x["step"] > 200 and x.get("testenv", 0) == 0,
    loc="lower left",
    list_indexes=[0, 3, 5]
)
plot.save_fig(fig, "diwa/fig_dnim_hist_dr_home0" + ".png")
