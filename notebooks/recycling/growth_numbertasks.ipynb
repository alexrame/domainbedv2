# %%
# %load_ext autoreload
# %autoreload 2
import sys
import collections
import numpy as np
# sys.path.append("/private/home/alexandrerame/domainbedv2/")
# sys.path.append("/private/home/alexandrerame/slurmconfig/notebook/data")

sys.path.append("/Users/alexandrerame/code_repository/codedev/domainbedv2")
sys.path.append("/Users/alexandrerame/code_repository/notebook/data")

from domainbed.codeplot import plot

plot.plt.rcParams["figure.figsize"] = (5, 5)
plot.plt.rcParams['text.usetex'] = True
plot.plt.rcParams['font.family'] = 'serif'
plot.plt.rcParams['font.serif'] = 'Times Roman'
plot.FORMAT_X = [1, 2,3,4,5]
# plot.FORMAT_X=1
# plot.FORMAT_Y=3
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plot.MUL = 0
plot.SIZE = "large"

# %%
dict_data_to_domains = {
    "home": ["Art", "Clipart", "Product", "Photo"],
    "pacs": ["Art", "Cartoon", "Photo", "Sketch"], 
    "terra": ["L100",  "L38" ,  "L43" ,  "L46"],        
    "vlcs": ["Caltech",  "LabelMe" ,  "SUN" ,  "VOC"],
    "came": ["hospital 0",  "hospital 1" ,  "hospital 2" ,  "hospital 3"],                
}

# %%
# (pytorch) alexandrerame@devfair0751:~/slurmconfig/infrecycle/home/runs$ cat enshome_erm_recycle1to5.slurm_1651712.out | grep "&&"
home0 = []
home0.append({"acc": 0.6833333333333332, "acc_conf": 0.0012116365623076287, "acc_std": 0.005418603434688035, "dirs": "home_ma_fpacs_lp_0926", "dirslen": 1.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 20, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
# home0.append({"acc": 0.6875978574371651, "acc_conf": 0.0009309719671032121, "acc_std": 0.009309719671032122, "dirs": "home_ma_fpacs_lp_0926", "dirslen": 1.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
# home0.append({"acc": 0.690103007828595, "acc_conf": 0.0009719447539091172, "acc_std": 0.009719447539091172, "dirs": "home_ma_fpacs_lp_0926,home_ma_fdn_lp_0926", "dirslen": 2.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
# home0.append({"acc": 0.6944128553770086, "acc_conf": 0.0009196372793799418, "acc_std": 0.009196372793799418, "dirs": "home_ma_fpacs_lp_0926,home_ma_fdn_lp_0926,home_ma_lp_0926", "dirslen": 3.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
# home0.append({"acc": 0.6977832715286363, "acc_conf": 0.0006214568755012462, "acc_std": 0.006214568755012462, "dirs": "home_ma_fpacs_lp_0926,home_ma_fdn_lp_0926,home_ma_lp_0926,home_ma_fterrau_lp_0926", "dirslen": 4.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
# home0.append({"acc": 0.6954594149155336, "acc_conf": 0.0004714574578311463, "acc_std": 0.004714574578311463, "dirs": "home_ma_fpacs_lp_0926,home_ma_fdn_lp_0926,home_ma_lp_0926,home_ma_fterrau_lp_0926,home_ma_fvlcsu_lp_0926", "dirslen": 5.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})

home0.append({"acc": 0.6916975690152454, "acc_conf": 0.001099179930717674, "acc_std": 0.010991799307176739, "dirs": "home_ma_fpacs_lp_0926,home_ma_fdn_lp_0926", "dirslen": 2.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-10", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
home0.append({"acc": 0.6948166460651011, "acc_conf": 0.0008745335286186289, "acc_std": 0.00874533528618629, "dirs": "home_ma_fpacs_lp_0926,home_ma_fdn_lp_0926,home_ma_lp_0926", "dirslen": 3.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-7", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
home0.append({"acc": 0.6945817882159045, "acc_conf": 0.0007133825742857037, "acc_std": 0.007133825742857036, "dirs": "home_ma_fpacs_lp_0926,home_ma_fdn_lp_0926,home_ma_lp_0926,home_ma_fterrau_lp_0926", "dirslen": 4.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-5", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
home0.append({"acc": 0.6966007416563659, "acc_conf": 0.00026939255182273163, "acc_std": 0.0026939255182273163, "dirs": "home_ma_fpacs_lp_0926,home_ma_fdn_lp_0926,home_ma_lp_0926,home_ma_fterrau_lp_0926,home_ma_fvlcsu_lp_0926", "dirslen": 5.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-4", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})

# %%
pacs0 = []

# (pytorch) alexandrerame@devfair0751:~/slurmconfig/infrecycle/pacs/runs$ cat enspacs_erm_recycle1to5.slurm_1651730.out| grep "&&"
pacs0.append({"acc": 0.899755859375, "acc_conf": 0.0014766370966399769, "acc_std": 0.006603721852369829, "dirs": "pacs_ma_fhome_lp_0926", "dirslen": 1.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 20, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
# pacs0.append({"acc": 0.9047314453125, "acc_conf": 0.0010964256257292317, "acc_std": 0.010964256257292316, "dirs": "pacs_ma_fhome_lp_0926", "dirslen": 1.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
pacs0.append({"acc": 0.90376953125, "acc_conf": 0.0006155319220959548, "acc_std": 0.006155319220959549, "dirs": "pacs_ma_fhome_lp_0926,pacs_ma_fdn_lp_0926", "dirslen": 2.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
pacs0.append({"acc": 0.9041015625, "acc_conf": 0.0005172555746125638, "acc_std": 0.0051725557461256375, "dirs": "pacs_ma_fhome_lp_0926,pacs_ma_fdn_lp_0926,pacs_ma_lp_0926", "dirslen": 3.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
pacs0.append({"acc": 0.905126953125, "acc_conf": 0.0004814710629523327, "acc_std": 0.004814710629523327, "dirs": "pacs_ma_fhome_lp_0926,pacs_ma_fdn_lp_0926,pacs_ma_lp_0926,pacs_ma_fterrau_lp_0926", "dirslen": 4.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
pacs0.append({"acc": 0.904609375, "acc_conf": 0.00042176421794883485, "acc_std": 0.004217642179488348, "dirs": "pacs_ma_fhome_lp_0926,pacs_ma_fdn_lp_0926,pacs_ma_lp_0926,pacs_ma_fterrau_lp_0926,pacs_ma_fvlcsu_lp_0926", "dirslen": 5.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})

# (pytorch) alexandrerame@devfair0751:~/slurmconfig/infrecycle/pacs/runs$ cat enspacs_erm_recycle1to5v2.slurm_1665107.out | grep "&&"
# {"acc": 0.9043017578125, "acc_conf": 0.0006575136280460536, "acc_std": 0.006575136280460536, "dirs": "pacs_ma_fhome_lp_0926,pacs_ma_fdn_lp_0926", "dirslen": 2.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-10", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"}
# {"acc": 0.9040380859375, "acc_conf": 0.0005660885676316014, "acc_std": 0.0056608856763160145, "dirs": "pacs_ma_fhome_lp_0926,pacs_ma_fdn_lp_0926,pacs_ma_lp_0926", "dirslen": 3.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-7", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"}
# {"acc": 0.9046337890625, "acc_conf": 0.00037738139278712226, "acc_std": 0.0037738139278712226, "dirs": "pacs_ma_fhome_lp_0926,pacs_ma_fdn_lp_0926,pacs_ma_lp_0926,pacs_ma_fterrau_lp_0926", "dirslen": 4.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-5", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"}
# {"acc": 0.904287109375, "acc_conf": 0.0003570788462359528, "acc_std": 0.0035707884623595284, "dirs": "pacs_ma_fhome_lp_0926,pacs_ma_fdn_lp_0926,pacs_ma_lp_0926,pacs_ma_fterrau_lp_0926,pacs_ma_fvlcsu_lp_0926", "dirslen": 5.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-4", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"}

# %%
vlcs0 = []
# (pytorch) alexandrerame@devfair0751:~/slurmconfig/infrecycle/vlcs/runs$ cat ensvlcs_erm_recycle1to5.slurm_1651824.out | grep "&&"
vlcs0.append({"acc": 0.9902473498233215, "acc_conf": 0.00022123640766781886, "acc_std": 0.0009893992932861974, "dirs": "vlcs_ma_fhome_lp_0926", "dirslen": 1.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 20, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
# vlcs0.append({"acc": 0.9902402826855127, "acc_conf": 9.197873749911207e-05, "acc_std": 0.0009197873749911207, "dirs": "vlcs_ma_fhome_lp_0926", "dirslen": 1.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
# vlcs0.append({"acc": 0.9915759717314486, "acc_conf": 0.00013655495204821998, "acc_std": 0.0013655495204821998, "dirs": "vlcs_ma_fhome_lp_0926,vlcs_ma_fdn_lp_0926", "dirslen": 2.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
# vlcs0.append({"acc": 0.9920777385159011, "acc_conf": 0.0001360474506887823, "acc_std": 0.0013604745068878231, "dirs": "vlcs_ma_fhome_lp_0926,vlcs_ma_fdn_lp_0926,vlcs0_erm_lp_0926", "dirslen": 3.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
# vlcs0.append({"acc": 0.9919858657243816, "acc_conf": 0.00013528355194234923, "acc_std": 0.0013528355194234924, "dirs": "vlcs_ma_fhome_lp_0926,vlcs_ma_fdn_lp_0926,vlcs0_erm_lp_0926,vlcs_ma_fterra_lp_0926", "dirslen": 4.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
# vlcs0.append({"acc": 0.9919293286219082, "acc_conf": 0.00014660862125841028, "acc_std": 0.0014660862125841028, "dirs": "vlcs_ma_fhome_lp_0926,vlcs_ma_fdn_lp_0926,vlcs0_erm_lp_0926,vlcs_ma_fterra_lp_0926,vlcs_ma_fpacs_lp_0926", "dirslen": 5.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})

# (pytorch) alexandrerame@devfair0751:~/slurmconfig/infrecycle/vlcs/runs$ cat ensvlcs_erm_recycle1to5v2.slurm_1665068.out | grep "&&"
vlcs0.append({"acc": 0.9915901060070672, "acc_conf": 0.00015041552405507263, "acc_std": 0.0015041552405507263, "dirs": "vlcs_ma_fhome_lp_0926,vlcs_ma_fdn_lp_0926", "dirslen": 2.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-10", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
vlcs0.append({"acc": 0.9920424028268552, "acc_conf": 0.00012347080583327775, "acc_std": 0.0012347080583327776, "dirs": "vlcs_ma_fhome_lp_0926,vlcs_ma_fdn_lp_0926,vlcs0_erm_lp_0926", "dirslen": 3.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-7", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
vlcs0.append({"acc": 0.9920706713780919, "acc_conf": 0.00013015050975640155, "acc_std": 0.0013015050975640156, "dirs": "vlcs_ma_fhome_lp_0926,vlcs_ma_fdn_lp_0926,vlcs0_erm_lp_0926,vlcs_ma_fterra_lp_0926", "dirslen": 4.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-5", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
vlcs0.append({"acc": 0.9921625441696114, "acc_conf": 0.00013224992373498802, "acc_std": 0.0013224992373498802, "dirs": "vlcs_ma_fhome_lp_0926,vlcs_ma_fdn_lp_0926,vlcs0_erm_lp_0926,vlcs_ma_fterra_lp_0926,vlcs_ma_fpacs_lp_0926", "dirslen": 5.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-4", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})

# %%
terra0 = []
# (pytorch) alexandrerame@devfair0751:~/slurmconfig/infrecycle/terra/runs$ cat ensterra_erm_recycle1to5v2.slurm_1665211.out | grep "&&"
terra0.append({"acc": 0.5784707867538494, "acc_conf": 0.0010016183402986266, "acc_std": 0.010016183402986266, "dirs": "terra_ma_fhome_lp_0926", "dirslen": 1.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-20", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
# terra0.append({"acc": 0.5778591014553892, "acc_conf": 0.001088781177921796, "acc_std": 0.01088781177921796, "dirs": "terra_ma_fhome_lp_0926,terra_ma_fdn_lp_0926", "dirslen": 2.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-10", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
# terra0.append({"acc": 0.5779012866483864, "acc_conf": 0.0009610915370956369, "acc_std": 0.00961091537095637, "dirs": "terra_ma_fhome_lp_0926,terra_ma_fdn_lp_0926,terra0_erm_lp_0926", "dirslen": 3.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-7", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
# terra0.append({"acc": 0.5767433031006116, "acc_conf": 0.0010711809042042932, "acc_std": 0.010711809042042933, "dirs": "terra_ma_fhome_lp_0926,terra_ma_fdn_lp_0926,terra0_erm_lp_0926,terra_ma_fvlcs_lp_0926", "dirslen": 4.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-5", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
# terra0.append({"acc": 0.5764205863741827, "acc_conf": 0.0010434748384970166, "acc_std": 0.010434748384970166, "dirs": "terra_ma_fhome_lp_0926,terra_ma_fdn_lp_0926,terra0_erm_lp_0926,terra_ma_fvlcs_lp_0926,terra_ma_fpacsu_lp_0926", "dirslen": 5.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 100, "step": "best", "testenv": 0, "topk": "-4", "trialseed": 0.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})

# (pytorch) alexandrerame@devfair0751:~/slurmconfig/infrecycle/terra/runs$ cat ensterra_erm_recycle1to2_t1topk.slurm_1687690.out | grep "&&"
# terra0.append({"acc": 0.5781691626239189, "acc_conf": 0.003049002736271315, "acc_std": 0.016700075765507742, "dirs": "terra_ma_fhome_lp_0926", "dirslen": 1.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 6.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 6.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 30, "step": "best", "testenv": 0, "topk": "-6", "trialseed": 1.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
terra0.append({"acc": 0.5820502003796667, "acc_conf": 0.0016900056754379086, "acc_std": 0.00925654230749097, "dirs": "terra_ma_fhome_lp_0926,terra_ma_fdn_lp_0926", "dirslen": 2.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 12.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 12.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 30, "step": "best", "testenv": 0, "topk": "-6", "trialseed": 1.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
# (pytorch) alexandrerame@devfair0751:~/slurmconfig/infrecycle/terra/runs$ cat ensterra_erm_recycle1to5_t1topk.slurm_1686809.out | grep "&&"
terra0.append({"acc": 0.5839625957955424, "acc_conf": 0.0011669408278622174, "acc_std": 0.006391598146938895, "dirs": "terra_ma_fhome_lp_0926,terra_ma_fdn_lp_0926,terra0_erm_lp_0926", "dirslen": 3.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 18.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 18.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 30, "step": "best", "testenv": 0, "topk": "-6", "trialseed": 1.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
terra0.append({"acc": 0.5833720030935808, "acc_conf": 0.0012816896908968145, "acc_std": 0.007020103554260091, "dirs": "terra_ma_fhome_lp_0926,terra_ma_fdn_lp_0926,terra0_erm_lp_0926,terra_ma_fvlcs_lp_0926", "dirslen": 4.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 30, "step": "best", "testenv": 0, "topk": "-5", "trialseed": 1.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})
terra0.append({"acc": 0.5845250650355058, "acc_conf": 0.0014672351129364789, "acc_std": 0.008036377685189494, "dirs": "terra_ma_fhome_lp_0926,terra_ma_fdn_lp_0926,terra0_erm_lp_0926,terra_ma_fvlcs_lp_0926,terra_ma_fpacsu_lp_0926", "dirslen": 5.0, "dirslen_conf": 0.0, "dirslen_std": 0.0, "length": 20.0, "length_conf": 0.0, "length_std": 0.0, "lengthf": 20.0, "lengthf_conf": 0.0, "lengthf_std": 0.0, "numsamples": 30, "step": "best", "testenv": 0, "topk": "-4", "trialseed": 1.0, "trialseed_conf": 0.0, "trialseed_std": 0.0, "printres": "&&"})

# %%
dict_data_to_l = {"home": [home0], "pacs": [pacs0], "vlcs": [vlcs0], "terra": [terra0]}

# %%
testenv = 0
labels = ["Model ratatouille"]

# %%
dataset = "terra"
plot.dict_key_to_label["acc"] = "OOD test acc. on domain " + dict_data_to_domains[dataset][testenv]
fig = plot.plot_key(
    [dict_data_to_l[dataset][testenv]],
    labels=labels,
    key1="dirslen",
    key2="acc",
    # keyclustering="dirslen",
    lambda_filtering=lambda x: x.get("testenv", 0) == testenv,
    loc="lower right",
    order="2log",
    list_indexes=[0]
)
plot.save_fig(fig, "trainingcost/countaux_" + dataset + str(testenv) + ".pdf")

# %%
dataset = "home"
plot.dict_key_to_label["acc"] = "OOD test acc. on domain " + dict_data_to_domains[dataset][testenv]
fig = plot.plot_key(
    [dict_data_to_l[dataset][testenv]],
    labels=labels,
    key1="dirslen",
    key2="acc",
    # keyclustering="dirslen",
    lambda_filtering=lambda x: x.get("testenv", 0) == testenv,
    loc="lower right",
    order="2log",
    list_indexes=[0]
)
plot.save_fig(fig, "trainingcost/countaux_" + dataset + str(testenv) + ".pdf")

# %%
dataset = "vlcs"
plot.dict_key_to_label["acc"] = "OOD test acc. on domain " + dict_data_to_domains[dataset][testenv]
fig = plot.plot_key(
    [dict_data_to_l[dataset][testenv]],
    labels=labels,
    key1="dirslen",
    key2="acc",
    # keyclustering="dirslen",
    lambda_filtering=lambda x: x.get("testenv", 0) == testenv,
    loc="lower right",
    order="2log",
    list_indexes=[0]
)
plot.save_fig(fig, "trainingcost/countaux_" + dataset + str(testenv) + ".pdf")

# %%
dataset = "pacs"
plot.dict_key_to_label["acc"] = "OOD test acc. on domain " + dict_data_to_domains[dataset][testenv]
fig = plot.plot_key(
    [dict_data_to_l[dataset][testenv]],
    labels=labels,
    key1="dirslen",
    key2="acc",
    # keyclustering="dirslen",
    lambda_filtering=lambda x: x.get("testenv", 0) == testenv,
    loc="lower right",
    order="2log",
    list_indexes=[0]
)
plot.save_fig(fig, "trainingcost/countaux_" + dataset + str(testenv) + ".pdf")
